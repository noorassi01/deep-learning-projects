# %% [markdown]
# <a
# href="https://colab.research.google.com/github/wingated/cs474_labs_f2019/blob/master/DL_Lab7.ipynb"
#   target="_parent">
#   <img
#     src="https://colab.research.google.com/assets/colab-badge.svg"
#     alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Lab 7: The Transformer
# ### Description:
# For this lab, you will fill in the attention mechanism for the Transformer architecture.
#
# There are three parts of this lab:
# 1. Implement scaled dot-product attention
# 2. Implement a multi-headded attention mechanism
# 3. Translate general conference!
#
#
# ### Grading standards
#
# Your code will be graded on the following:
#
# - 45% Implementation of scaled dot-product attention
# - 45% Implementation of multi-headed attention mechanism
# - 10% Reasonable translation of general conference
#
# Note: This lab was adapted from "The Annotated Transformer", a publically available PyTorch implementation of the Transformer. This lab only requires about 20 lines of code, but we want you to think hard about the dimensions on which different operations apply, and debug accordingly. This will be trivial if you use the implementation for reference, but will be a worthwhile learning exercise if you don't. So we ask you not to reference that particular implementation, though you are free to reference other implementations (see references below).
#
#
# ### Tips:
# A couple of tips for this lab:
# 0. The provided code instantiates the `MultiHeadedAttention` class for you. For a start, try printing the dimensions of `key`, `query`, and `values` in the `forward()` function the `MultiHeadedAttention` class.
# 1. The key to this lab is section 3.2 of "Attention is All you Need". This section will tell you pretty much all you need to know about dimensions. https://arxiv.org/pdf/1706.03762.pdf
# 2. The queries, keys, and values come in the form N x L x d_model, where N is the batch size, L is the sentence length, and d_model is the dimension of the embedding. Both the batch size and the sentence length vary across training instances. Think about what each dimension means to find out which dimensions you'll want to perform each operation on.
# 3. There are 3 pytorch implementations of matrix multiplication: torch.bmm, torch.mm, and torch.matmul. You'll want to figure out which one to use for this lab.
# 4. There are 3 pytorch implementations of transpose: torch.t, torch.transpose, and torch.permute. You'll want to figure out which one of those to use as well.
# 5. This implementation provides a `clones()` function that you may find useful in the MultiHeadedAttention class
#
# ### Example Output
# An example of my final samples are shown below, after 3 epochs through the data. You should expect each epoch to take ~10 minutes, and should see reasonable results after the first epoch.
#
# Spanish:	Muchos miembros de la Iglesia tuvieron fe en las profecías de Brigham Young , mientras que otros se mostraron escépticos y partieron hacia lo que ellos creían que sería una vida mejor .
#
# Translation:	Many members of the Church had faith in Brigham Young , while others who showed and other mocking to what they would be better than they would be better better than they would better .
#
# Target:		Many Church members had faith in Brigham Young ’s prophecies , while others remained <unk> and left for what they assumed would be a better life .

# %% [markdown]
# ### Based on "Attention is All You Need" (https://arxiv.org/abs/1706.03762) and "The Annotated Transformer" (https://nlp.seas.harvard.edu/2018/04/03/attention.html)
# ### Also useful:
# http://jalammar.github.io/illustrated-transformer/
#
# https://github.com/jadore801120/attention-is-all-you-need-pytorch/blob/master/transformer/

# %% [markdown]
# ## Setup

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import math, copy, time
from torch.autograd import Variable
import matplotlib.pyplot as plt
import seaborn
seaborn.set_context(context="talk")
# %matplotlib inline

# Download english and spanish vocab and general conference texts
# !pip install torchtext==0.6.0
# !pip install spacy
# !python -m spacy download en_core_web_sm
# !python -m spacy download es_core_news_sm
# !wget  -O ./spanish "https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_es.txt"
# !wget -O ./english "https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_en.txt"
# Out:
# Collecting torchtext==0.6.0
#   Downloading torchtext-0.6.0-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from torchtext==0.6.0) (4.66.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchtext==0.6.0) (2.31.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from torchtext==0.6.0) (2.1.0+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchtext==0.6.0) (1.23.5)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from torchtext==0.6.0) (1.16.0)
# Collecting sentencepiece (from torchtext==0.6.0)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 13.2 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.6.0) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.6.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.6.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchtext==0.6.0) (2023.7.22)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.6.0) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.6.0) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.6.0) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.6.0) (3.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.6.0) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.6.0) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->torchtext==0.6.0) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->torchtext==0.6.0) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->torchtext==0.6.0) (1.3.0)
# Installing collected packages: sentencepiece, torchtext
#   Attempting uninstall: torchtext
#     Found existing installation: torchtext 0.16.0
#     Uninstalling torchtext-0.16.0:
#       Successfully uninstalled torchtext-0.16.0
# Successfully installed sentencepiece-0.1.99 torchtext-0.6.0
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.10.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.10.13)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.3)
# 2023-10-29 04:59:08.101816: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-29 04:59:08.101876: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-29 04:59:08.101912: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-10-29 04:59:08.109623: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-29 04:59:09.184111: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-10-29 04:59:10.464206: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-29 04:59:10.464682: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-29 04:59:10.464882: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# Collecting en-core-web-sm==3.6.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.6.0/en_core_web_sm-3.6.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 36.4 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.7.0,>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from en-core-web-sm==3.6.0) (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.10.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.10.13)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.1.3)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# 2023-10-29 04:59:21.777590: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-29 04:59:21.777647: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-29 04:59:21.777680: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-10-29 04:59:21.785050: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-29 04:59:22.859272: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-10-29 04:59:24.122769: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-29 04:59:24.123191: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-29 04:59:24.123375: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# Collecting es-core-news-sm==3.6.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-3.6.0/es_core_news_sm-3.6.0-py3-none-any.whl (12.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 37.1 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.7.0,>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from es-core-news-sm==3.6.0) (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->es-core-news-sm==3.6.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->es-core-news-sm==3.6.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->es-core-news-sm==3.6.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->es-core-news-sm==3.6.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->es-core-news-sm==3.6.0) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->es-core-news-sm==3.6.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->es-core-news-sm==3.6.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->es-core-news-sm==3.6.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->es-core-news-sm==3.6.0) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->es-core-news-sm==3.6.0) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->es-core-news-sm==3.6.0) (0.10.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->es-core-news-sm==3.6.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->es-core-news-sm==3.6.0) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->es-core-news-sm==3.6.0) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->es-core-news-sm==3.6.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->es-core-news-sm==3.6.0) (1.10.13)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->es-core-news-sm==3.6.0) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->es-core-news-sm==3.6.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->es-core-news-sm==3.6.0) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->es-core-news-sm==3.6.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->es-core-news-sm==3.6.0) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->es-core-news-sm==3.6.0) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->es-core-news-sm==3.6.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->es-core-news-sm==3.6.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->es-core-news-sm==3.6.0) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->es-core-news-sm==3.6.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->es-core-news-sm==3.6.0) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->es-core-news-sm==3.6.0) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.7.0,>=3.6.0->es-core-news-sm==3.6.0) (2.1.3)
# Installing collected packages: es-core-news-sm
# Successfully installed es-core-news-sm-3.6.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')
# --2023-10-29 04:59:31--  https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_es.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8617078 (8.2M) [text/plain]
# Saving to: ‘./spanish’
#
# ./spanish           100%[===================>]   8.22M  --.-KB/s    in 0.06s
#
# 2023-10-29 04:59:31 (144 MB/s) - ‘./spanish’ saved [8617078/8617078]
#
# --2023-10-29 04:59:31--  https://raw.githubusercontent.com/nickwalton/translation/master/gc_2010-2017_conglomerated_20171009_en.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7755011 (7.4M) [text/plain]
# Saving to: ‘./english’
#
# ./english           100%[===================>]   7.40M  --.-KB/s    in 0.06s
#
# 2023-10-29 04:59:31 (119 MB/s) - ‘./english’ saved [7755011/7755011]

# %% [markdown]
# # Model

# %% [markdown]
# ## Model Helpers

# %%
class PositionwiseFeedForward(nn.Module):
    "Simple linear layers with dropout and relu"
    def __init__(self, d_model, d_ff, dropout=0.1):
        super(PositionwiseFeedForward, self).__init__()
        self.w_1 = nn.Linear(d_model, d_ff)
        self.w_2 = nn.Linear(d_ff, d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        return self.w_2(self.dropout(F.relu(self.w_1(x))))

class Embeddings(nn.Module):
    "Create word embeddings"
    def __init__(self, d_model, vocab):
        super(Embeddings, self).__init__()
        self.lut = nn.Embedding(vocab, d_model)
        self.d_model = d_model

    def forward(self, x):
        return self.lut(x) * math.sqrt(self.d_model)

class Generator(nn.Module):
    "Define standard linear + softmax generation step."
    def __init__(self, d_model, vocab):
        super(Generator, self).__init__()
        self.proj = nn.Linear(d_model, vocab)

    def forward(self, x):
        return F.log_softmax(self.proj(x), dim=-1)

class LayerNorm(nn.Module):
    "Construct a layernorm module "
    def __init__(self, features, eps=1e-6):
        super(LayerNorm, self).__init__()
        self.a_2 = nn.Parameter(torch.ones(features))
        self.b_2 = nn.Parameter(torch.zeros(features))
        self.eps = eps

    def forward(self, x):
        mean = x.mean(-1, keepdim=True)
        std = x.std(-1, keepdim=True)
        return self.a_2 * (x - mean) / (std + self.eps) + self.b_2

class SublayerConnection(nn.Module):
    """
    A residual connection followed by a layer norm.
    Note for code simplicity the norm is first as opposed to last.
    """
    def __init__(self, size, dropout):
        super(SublayerConnection, self).__init__()
        self.norm = LayerNorm(size)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, sublayer):
        "Apply residual connection to any sublayer with the same size."
        return x + self.dropout(sublayer(self.norm(x)))

def clones(module, N):
    "Produce N identical layers."
    return nn.ModuleList([copy.deepcopy(module) for _ in range(N)])

# %% [markdown]
# ## Encoder
#
# The encoder is composed of a stack of $N=6$ identical layers.

# %%
class Encoder(nn.Module):
    "Core encoder is a stack of N layers"
    def __init__(self, layer, N):
        super(Encoder, self).__init__()
        self.layers = clones(layer, N)
        self.norm = LayerNorm(layer.size)

    def forward(self, x, mask):
        "Pass the input (and mask) through each layer in turn."
        for layer in self.layers:
            x = layer(x, mask)
        return self.norm(x)



class EncoderLayer(nn.Module):
    "Encoder is made up of self-attn and feed forward "
    def __init__(self, size, self_attn, feed_forward, dropout):
        super(EncoderLayer, self).__init__()
        self.self_attn = self_attn
        self.feed_forward = feed_forward
        self.sublayer = clones(SublayerConnection(size, dropout), 2)
        self.size = size

    def forward(self, x, mask):
        "Follow Figure 1 (left) for connections."
        x = self.sublayer[0](x, lambda x: self.self_attn(x, x, x, mask))
        return self.sublayer[1](x, self.feed_forward)

# %% [markdown]
# ## Decoder
#
# The decoder is also composed of a stack of $N=6$ identical layers.

# %%
class Decoder(nn.Module):
    "Generic N layer decoder with masking."
    def __init__(self, layer, N):
        super(Decoder, self).__init__()
        self.layers = clones(layer, N)
        self.norm = LayerNorm(layer.size)

    def forward(self, x, memory, src_mask, tgt_mask):
        for layer in self.layers:
            x = layer(x, memory, src_mask, tgt_mask)
        return self.norm(x)

class DecoderLayer(nn.Module):
    "Decoder is made of self-attn, src-attn, and feed forward (defined below)"
    def __init__(self, size, self_attn, src_attn, feed_forward, dropout):
        super(DecoderLayer, self).__init__()
        self.size = size
        self.self_attn = self_attn
        self.src_attn = src_attn
        self.feed_forward = feed_forward
        self.sublayer = clones(SublayerConnection(size, dropout), 3)

    def forward(self, x, memory, src_mask, tgt_mask):
        "Follow Figure 1 (right) for connections."
        m = memory
        x = self.sublayer[0](x, lambda x: self.self_attn(x, x, x, tgt_mask))
        x = self.sublayer[1](x, lambda x: self.src_attn(x, m, m, src_mask))
        return self.sublayer[2](x, self.feed_forward)

def subsequent_mask(size):
    "Mask out subsequent positions."
    attn_shape = (1, size, size)
    subsequent_mask = np.triu(np.ones(attn_shape), k=1).astype('uint8')
    return torch.from_numpy(subsequent_mask) == 0

# %% [markdown]
# ## Implement Attention
#
#
# https://arxiv.org/pdf/1706.03762.pdf

# %%
def attention(query, key, value, mask):
    # Compute 'Scaled Dot Product Attention'
    d_p = query.size(-1)
    QK = torch.matmul(query, key.transpose(-2, -1))
    scale = math.sqrt(d_p)
    scores = QK/scale

    # Apply the mask
    if mask is not None:
        scores = scores.masked_fill(mask == 0, -1e9)

    scores = F.softmax(scores, dim = -1)
    output = torch.matmul(scores, value)
    return output

# %%
class MultiHeadedAttention(nn.Module):
    def __init__(self, h, d_model, dropout=0.1):
        super(MultiHeadedAttention, self).__init__()

        self.num_heads = h
        self.dropout = dropout

        # Initialize linear layers for each head
        self.q_layers = clones(nn.Linear(d_model, d_model // h), h)
        self.k_layers = clones(nn.Linear(d_model, d_model // h), h)
        self.v_layers = clones(nn.Linear(d_model, d_model // h), h)


        # Final output linear layer
        self.final_linear_layer = nn.Linear(d_model, d_model)

    def forward(self, query, key, value, mask):
        head_results = []
        dropout_layer = nn.Dropout(self.dropout)

        # Loop through each attention head
        for i in range(self.num_heads):
            proj_q = self.q_layers[i](query)
            proj_k = self.k_layers[i](key)
            proj_v = self.v_layers[i](value)
            scaled_attention = attention(proj_q, proj_k, proj_v, mask)
            scaled_attention = dropout_layer(scaled_attention)
            head_results.append(scaled_attention)

        concatenated_heads = head_results[0]
        for head in head_results[1:]:
            concatenated_heads = torch.cat((concatenated_heads, head), dim=-1)

        return self.final_linear_layer(concatenated_heads)

# %% [markdown]
# ## Positional Encoding
# Since our model contains no recurrence and no convolution, in order for the model to make use of the order of the sequence, we must inject some information about the relative or absolute position of the tokens in the sequence.  To this end, we add "positional encodings" to the input embeddings at the bottoms of the encoder and decoder stacks.  The positional encodings have the same dimension $d_{\text{model}}$ as the embeddings, so that the two can be summed.   There are many choices of positional encodings, learned and fixed [(cite)](https://arxiv.org/pdf/1705.03122.pdf).
#
# In this work, we use sine and cosine functions of different frequencies:
# $$PE_{(pos,2i)} = sin(pos / 10000^{2i/d_{\text{model}}})$$
#
# $$PE_{(pos,2i+1)} = cos(pos / 10000^{2i/d_{\text{model}}})$$
# where $pos$ is the position and $i$ is the dimension.  That is, each dimension of the positional encoding corresponds to a sinusoid.  The wavelengths form a geometric progression from $2\pi$ to $10000 \cdot 2\pi$.  We chose this function because we hypothesized it would allow the model to easily learn to attend by relative positions, since for any fixed offset $k$, $PE_{pos+k}$ can be represented as a linear function of $PE_{pos}$.
#
# In addition, we apply dropout to the sums of the embeddings and the positional encodings in both the encoder and decoder stacks.  For the base model, we use a rate of $P_{drop}=0.1$.

# %%
class PositionalEncoding(nn.Module):
    "Implement the PE function."
    def __init__(self, d_model, dropout, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)

        # Compute the positional encodings once in log space.
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len).unsqueeze(1).float()
        div_term = 1 / (10000 ** (torch.arange(0., d_model, 2) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + Variable(self.pe[:, :x.size(1)],
                         requires_grad=False)
        return self.dropout(x)

# %%
plt.figure(figsize=(15, 5))
pe = PositionalEncoding(20, 0)
y = pe.forward(Variable(torch.zeros(1, 100, 20)))
plt.plot(np.arange(100), y[0, :, 4:8].data.numpy())
plt.legend(["dim %d"%p for p in [4,5,6,7]])
None

# %% [markdown]
# ## Full Model

# %%
class TransformerModel(nn.Module):
    """
    Full transformer model
    """
    def __init__(self, src_vocab, tgt_vocab, N=6, d_model=256, d_ff=1024, h=8, dropout=0.1):
        super(TransformerModel, self).__init__()

        attn = MultiHeadedAttention(h, d_model)
        ff = PositionwiseFeedForward(d_model, d_ff, dropout)
        position = PositionalEncoding(d_model, dropout)
        c = copy.deepcopy

        self.encoder = Encoder(EncoderLayer(d_model, c(attn), c(ff), dropout), N)
        self.decoder = Decoder(DecoderLayer(d_model, c(attn), c(attn),
                             c(ff), dropout), N)
        self.src_embed = nn.Sequential(Embeddings(d_model, src_vocab), c(position))
        self.tgt_embed = nn.Sequential(Embeddings(d_model, tgt_vocab), c(position))
        self.generator = Generator(d_model, tgt_vocab)
        for p in self.parameters():
            if p.dim() > 1:
                nn.init.xavier_uniform_(p)

    def forward(self, src, tgt, src_mask, tgt_mask):
        "Take in and process masked src and target sequences."
        return self.decode(self.encode(src, src_mask), src_mask,
                            tgt, tgt_mask)

    def encode(self, src, src_mask):
        return self.encoder(self.src_embed(src), src_mask)

    def decode(self, memory, src_mask, tgt, tgt_mask):
        return self.decoder(self.tgt_embed(tgt), memory, src_mask, tgt_mask)

# %% [markdown]
# # Training

# %% [markdown]
# ## Batches and Masking

# %%
class Batch:
    "Object for holding a batch of data with mask during training."
    def __init__(self, src, trg=None, pad=0):
        self.src = src
        self.src_mask = (src != pad).unsqueeze(-2)
        if trg is not None:
            self.trg = trg[:, :-1]
            self.trg_y = trg[:, 1:]
            self.trg_mask = \
                self.make_std_mask(self.trg, pad)
            self.ntokens = (self.trg_y != pad).data.sum()

    @staticmethod
    def make_std_mask(tgt, pad):
        "Create a mask to hide padding and future words."
        tgt_mask = (tgt != pad).unsqueeze(-2)
        tgt_mask = tgt_mask & Variable(
            subsequent_mask(tgt.size(-1)).type_as(tgt_mask.data))
        return tgt_mask


global max_src_in_batch, max_tgt_in_batch
def batch_size_fn(new, count, sofar):
    "Keep augmenting batch and calculate total number of tokens + padding."
    global max_src_in_batch, max_tgt_in_batch
    if count == 1:
        max_src_in_batch = 0
        max_tgt_in_batch = 0
    max_src_in_batch = max(max_src_in_batch,  len(new.src))
    max_tgt_in_batch = max(max_tgt_in_batch,  len(new.trg) + 2)
    src_elements = count * max_src_in_batch
    tgt_elements = count * max_tgt_in_batch
    return max(src_elements, tgt_elements)

# %% [markdown]
# ## Label Smoothing
#
# During training, we employed label smoothing of value $\epsilon_{ls}=0.1$ [(cite)](https://arxiv.org/abs/1512.00567).  This hurts perplexity, as the model learns to be more unsure, but improves accuracy and BLEU score.

# %%
class LabelSmoothing(nn.Module):
    "Implement label smoothing."
    def __init__(self, size, padding_idx, smoothing=0.0):
        super(LabelSmoothing, self).__init__()
        self.criterion = nn.KLDivLoss(reduction='sum')
        self.padding_idx = padding_idx
        self.confidence = 1.0 - smoothing
        self.smoothing = smoothing
        self.size = size
        self.true_dist = None

    def forward(self, x, target):
        assert x.size(1) == self.size
        true_dist = x.data.clone()
        true_dist.fill_(self.smoothing / (self.size - 2))
        true_dist.scatter_(1, target.data.unsqueeze(1), self.confidence)
        true_dist[:, self.padding_idx] = 0
        mask = torch.nonzero(target.data == self.padding_idx)
        if mask.dim() > 0:
            true_dist.index_fill_(0, mask.squeeze(), 0.0)
        self.true_dist = true_dist
        return self.criterion(x, Variable(true_dist, requires_grad=False))

# %% [markdown]
# ## Data Loading

# %%
from torchtext import data, datasets
import torchtext
import spacy

# Load spacy tokenizers.
spacy_es = spacy.load('es_core_news_sm')
spacy_en = spacy.load('en_core_web_sm')

def tokenize_es(text):
    return [tok.text for tok in spacy_es.tokenizer(text)]

def tokenize_en(text):
    return [tok.text for tok in spacy_en.tokenizer(text)]

BOS_WORD = '<s>'
EOS_WORD = '</s>'
BLANK_WORD = "<blank>"
SRC = data.Field(tokenize=tokenize_es, pad_token=BLANK_WORD)
TGT = data.Field(tokenize=tokenize_en, init_token = BOS_WORD,
                 eos_token = EOS_WORD, pad_token=BLANK_WORD)

print("Loading Dataset")
with open('./spanish', 'r', encoding='utf-8') as spanish_text:
  spanish_lines = list(spanish_text)
with open('./english', 'r', encoding='utf-8') as english_text:
  english_lines = list(english_text)

fields = (["src", SRC], ["trg", TGT])
examples = [data.Example.fromlist((spanish_lines[i], english_lines[i]), fields ) for i in range(len(english_lines))]

MAX_LEN = 200
train, val = data.Dataset(examples, fields=fields, filter_pred=lambda x: len(vars(x)['src']) <= MAX_LEN and
        len(vars(x)['trg']) <= MAX_LEN).split()

MIN_FREQ = 1
SRC.build_vocab(train.src, min_freq=MIN_FREQ)
TGT.build_vocab(train.trg, min_freq=MIN_FREQ)
# Out:
# Loading Dataset

# %% [markdown]
# ## Training Code

# %%
class LossFunction:
    "A simple loss compute and train function."
    def __init__(self, generator, criterion, opt=None):
        self.generator = generator
        self.criterion = criterion
        self.opt = opt

    def __call__(self, x, y, norm):
        x = self.generator(x)
        loss = self.criterion(x.contiguous().view(-1, x.size(-1)),
                              y.contiguous().view(-1)) / norm
        loss.backward()
        if self.opt is not None:
            self.opt.step()
            self.opt.zero_grad()
        return loss.data * norm

class DataIterator(data.Iterator):
    def create_batches(self):
        if self.train:
            def pool(d, random_shuffler):
                for p in data.batch(d, self.batch_size * 100):
                    p_batch = data.batch(
                        sorted(p, key=self.sort_key),
                        self.batch_size, self.batch_size_fn)
                    for b in random_shuffler(list(p_batch)):
                        yield b
            self.batches = pool(self.data(), self.random_shuffler)

        else:
            self.batches = []
            for b in data.batch(self.data(), self.batch_size,
                                          self.batch_size_fn):
                self.batches.append(sorted(b, key=self.sort_key))

def rebatch(pad_idx, batch):
    "Fix order in torchtext to match ours"
    src, trg = batch.src.transpose(0, 1).cuda(), batch.trg.transpose(0, 1).cuda()
    return Batch(src, trg, pad_idx)


def run_epoch(data_iter, model, loss_compute):
    "Standard Training and Logging Function"
    start = time.time()
    total_tokens = 0
    total_loss = 0
    tokens = 0
    for i, batch in enumerate(data_iter):
        out = model.forward(batch.src, batch.trg,
                            batch.src_mask, batch.trg_mask)
        loss = loss_compute(out, batch.trg_y, batch.ntokens)
        total_loss += loss
        total_tokens += batch.ntokens
        tokens += batch.ntokens
        if i % 50 == 1:
            elapsed = time.time() - start
            print("Epoch Step: %d Loss: %f Tokens per Sec: %f" %
                    (i, loss / batch.ntokens, tokens / elapsed))
            start = time.time()
            tokens = 0
    return total_loss / total_tokens

# %% [markdown]
# ## Train

# %%
import gc
gc.collect()

pad_idx = TGT.vocab.stoi["<blank>"]
model = TransformerModel(len(SRC.vocab), len(TGT.vocab), N=2).cuda()
n_epochs = 3
device = torch.device('cuda')

def scope():
    criterion = LabelSmoothing(size=len(TGT.vocab), padding_idx=pad_idx, smoothing=0.1)
    criterion.cuda()
    BATCH_SIZE = 1000
    train_iter = DataIterator(train, batch_size=BATCH_SIZE, device=device,
                            repeat=False, sort_key=lambda x: (len(x.src), len(x.trg)),
                            batch_size_fn=batch_size_fn, train
# %%
def greedy_decode(model, src, src_mask, max_len, start_symbol):
    memory = model.encode(src, src_mask)
    ys = torch.ones(1, 1).fill_(start_symbol).type_as(src.data)
    for i in range(max_len-1):
        out = model.decode(memory, src_mask,
                           Variable(ys),
                           Variable(subsequent_mask(ys.size(1))
                                    .type_as(src.data)))
        prob = model.generator(out[:, -1])
        _, next_word = torch.max(prob, dim = 1)
        next_word = next_word.data[0]
        ys = torch.cat([ys,
                        torch.ones(1, 1).type_as(src.data).fill_(next_word)], dim=1)
    return ys

BATCH_SIZE = 1000
n_train_iters = len(train) / BATCH_SIZE
valid_iter = DataIterator(val, batch_size=BATCH_SIZE, device=device,
                        repeat=False, sort_key=lambda x: (len(x.src), len(x.trg)),
                        batch_size_fn=batch_size_fn, train=False)

for i, batch in enumerate(valid_iter):
    src = batch.src.transpose(0, 1)[:1].cuda()
    src_mask = (src != SRC.vocab.stoi["<blank>"]).unsqueeze(-2).cuda()
    out = greedy_decode(model, src, src_mask,
                        max_len=60, start_symbol=TGT.vocab.stoi["<s>"])
    print("Spanish:", end="\t")
    for i in range(0, src.size(1)):
        sym = SRC.vocab.itos[src[0, i]]
        if sym == "</s>": break
        print(sym, end =" ")
    print()
    print("Translation:", end="\t")
    for i in range(1, out.size(1)):
        sym = TGT.vocab.itos[out[0, i]]
        if sym == "</s>": break
        print(sym, end =" ")
    print()
    print("Target:\t", end="\t")
    for i in range(1, batch.trg.size(0)):
        sym = TGT.vocab.itos[batch.trg.data[i, 0]]
        if sym == "</s>": break
        print(sym, end =" ")
    print()
    print()

    if i > 1000 and i<1100:
        break
# Out:
# Spanish:	de Jesús
# Translation:	The Jesus Christ of Jesus Christ of Jesus Christ of Jesus Christ
# Target:		See what God hath done .
#
# Spanish:	Los hermanos Cavalcante
# Translation:	The brethren to join her
# Target:		Cavalcante siblings
#
# Spanish:	De los Setenta
# Translation:	Of the Seventy
# Target:		Of the Seventy
#
# Spanish:	No hubo respuesta .
# Translation:	No answer was not answered .
# Target:		No response .
#
# Spanish:	Por Cheryl A. Esplin
# Translation:	By Cheryl A. Esplin
# Target:		By Cheryl A. Esplin
#
# Spanish:	Véase Alma 34:32 .
# Translation:	See Alma 32:28 .
# Target:		See Alma 34:32 .
#
# Spanish:	Hay muchos más .
# Translation:	There are many .
# Target:		There are many more .
#
# Spanish:	28 de <unk> de 2015
# Translation:	October 2015
# Target:		March 28 , 2015
#
# Spanish:	Doctrina y Convenios 100:16 .
# Translation:	Doctrine and Covenants 20:37 .
# Target:		Doctrine and Covenants 100:16 .
#
# Spanish:	Véase 3 Nefi 29 .
# Translation:	See 3 Nephi 3 Nephi 32:5 .
# Target:		See 3 Nephi 29 .
#
# Spanish:	Véase 2 Nefi 28:30 .
# Translation:	See 2 Nephi 2:25 .
# Target:		See 2 Nephi 28:30 .
#
# Spanish:	Tienes que aprender más .
# Translation:	You need to learn more .
# Target:		You need to learn more .
#
# Spanish:	Se preguntarán si los recuerdo
# Translation:	You can say if I remember if I remember the remember the memory of the I do .
# Target:		You ask , “ Do I remember you ? ”
#
# Spanish:	Conferencia General Semestral Núm . 186
# Translation:	186th Semiannual General Conference
# Target:		186th Semiannual General Conference
#
# Spanish:	Por el presidente Henry B. Eyring
# Translation:	By President Henry B. Eyring
# Target:		By President Henry B. Eyring
#
# Spanish:	que el <unk> entero sacudió ;
# Translation:	That will be able to get out .
# Target:		And shook the world about .
#
# Spanish:	Primer Consejero de la Primera Presidencia
# Translation:	First Counselor in the First Presidency
# Target:		First Counselor in the First Presidency
#
# Spanish:	Nos sentamos y <unk> <unk> .
# Translation:	We were able to announce and get us .
# Target:		We sat and <unk> <unk> .
#
# Spanish:	Dime la historia de Cristo .
# Translation:	Tell me the story of Christ .
# Target:		Tell me the stories of Jesus .
#
# Spanish:	No quería volver al hospital .
# Translation:	I did n’t want to go to the hospital .
# Target:		I was not going back to the hospital .
#
# Spanish:	Nuestro Salvador volvió a la vida .
# Translation:	Our Savior returned to life .
# Target:		Our Savior lived again .
#
# Spanish:	¡ Sacerdocio Aarónico , verdad sublime ,
# Translation:	Aaronic Priesthood , truth ,
# Target:		Aaronic Priesthood , truth sublime ,
#
# Spanish:	Él hizo eso conmigo esta noche .
# Translation:	He did this night .
# Target:		He did that for me tonight .
#
# Spanish:	Él cumple con todas Sus promesas .
# Translation:	He will be with all His promises .
# Target:		He fulfills all of His promises .
#
# Spanish:	Levantaos en fortaleza , hermanas de Sion
# Translation:	Rise on the Mountain of Zion
# Target:		Rise Up in Strength , Sisters in Zion
#
# Spanish:	“ no te dejaré ni te desampararé
# Translation:	“ I will not forget , neither would you forget thee .
# Target:		“ I will not fail thee , nor forsake thee .
#
# Spanish:	¡ Yo les testifico que lo es !
# Translation:	I testify that it is !
# Target:		I testify that it is !
#
# Spanish:	Ciertamente , Cristo fue nuestro mejor ejemplo .
# Translation:	Surely Christ was our best example .
# Target:		Christ was certainly our best example .
#
# Spanish:	Esto no es sólo una cuestión religiosa .
# Translation:	This is not only a religious freedom .
# Target:		This is not just a religious issue .
#
# Spanish:	y crean en las promesas de Dios !
# Translation:	And believe in the promises of God !
# Target:		And believe in the promises of God !
#
# Spanish:	Era un día extremadamente caluroso e <unk> .
# Translation:	It was a hot and trying to be able to be able to be a grandmother .
# Target:		It was an extremely hot and uncomfortable day .
#
# Spanish:	Además , <unk> <unk> <unk> a Agnes .
# Translation:	In addition to you find a shadow of their shoulders .
# Target:		They would also continue to make <unk> to Agnes .
#
# Spanish:	Jesús , gozo de los anhelos del hombre
# Translation:	Jesus Christ , amen
# Target:		3 . <unk> , Joy of Man ’s Desiring ( Organ Solo )
#
# Spanish:	Primera Consejera de la Presidencia General de la Primaria
# Translation:	First Counselor in the Primary General Presidency
# Target:		First Counselor in the Primary General Presidency
#
# Spanish:	Un joven en particular me llamó la atención ;
# Translation:	A young man in a particular teaching me .
# Target:		One particular young man caught our eye .
#
# Spanish:	Liahona , septiembre de 2014 , pág. 4 .
# Translation:	Ensign or Liahona , Nov. 2014 , 4 .
# Target:		Ensign or Liahona , Sept. 2014 , 4 .
#
# Spanish:	El abuelo dijo que había cumplido 70 años .
# Translation:	The grandfather said he had been thinking .
# Target:		He said that he had reached 70 years .
#
# Spanish:	Esos mandamientos vienen con esta promesa del Señor :
# Translation:	These commandments come with this promise :
# Target:		Those commandments come with this promise from the Lord :
#
# Spanish:	“ Mañana ” , respondió el hermano Krause .
# Translation:	“ Personal replied , “ Brother Mourik shall speak . ”
# Target:		“ Tomorrow , ” came the reply from Brother Krause .
#
# Spanish:	Isaías clamó : “ ¿ No has sabido ?
# Translation:	Isaiah said , “ Do not have ?
# Target:		“ Hast thou not known ? hast thou not heard ? ”
#
# Spanish:	La meta es llegar a ser una familia eterna .
# Translation:	The goal is to be a family .
# Target:		The goal is an eternal family .
#
# Spanish:	El Señor organiza familias eternas solamente en los templos .
# Translation:	The Lord eternal families only only only in temples .
# Target:		The Lord organizes eternal families only in temples .
#
# Spanish:	Michelle estaba divorciada e intentando criar a cuatro hijos .
# Translation:	He was trying to raise four children .
# Target:		Michelle was divorced and trying to raise four children .
#
# Spanish:	¿ Cómo podemos evitar esos pequeños errores de cálculo ?
# Translation:	How can we avoid these small mistakes ?
# Target:		How can we avoid these small errors in <unk> ?
#
# Spanish:	Debemos pedir con fe y con un corazón sincero .
# Translation:	We must ask with faith and a sincere heart .
# Target:		We must ask in faith and with an honest heart .
#
# Spanish:	Aquellos que no ven sus debilidades , no progresan .
# Translation:	Those who do not see their weaknesses , not .
# Target:		Those who do not see their weaknesses do not progress .
#
# Spanish:	Ninguno de ellos debería sentirse nunca excluido ni inútil .
# Translation:	No one of them should never forget or not .
# Target:		Not one of them should ever feel left out or useless .
#
# Spanish:	Yo sé que Dios vive y que las ama .
# Translation:	I know that God lives and loves you .
# Target:		I know that God lives and that He loves each and every one of you .
#
# Spanish:	Ver a los demás como lo que pueden llegar a ser
# Translation:	We will like others who can become become .
# Target:		See Others as They May Become
#
# Spanish:	Una relación entre personas del mismo sexo no se multiplica .
# Translation:	A relationship between people or they are not forgotten .
# Target:		A same - gender relationship does not multiply .
#
# Spanish:	Si no lo hacemos nosotros , ¿ quién lo hará ?
# Translation:	If we do not do ?
# Target:		If we do not do this , who will ?
#
# Spanish:	Por supuesto que también los misioneros ayudaron en gran medida .
# Translation:	Of course , the missionaries helped me in great as well as well .
# Target:		The missionaries , of course , added their important contribution .
#
# Spanish:	¿ Confiamos en que Sus mandamientos sean para nuestro bien ?
# Translation:	Do we trust that His commandments will be for our good ?
# Target:		Do we trust His commandments to be for our good ?
#
# Spanish:	El compartir esas verdades traerá más entusiasmo a tu vida .
# Translation:	The sharing these truths will help you more than your life .
# Target:		Sharing these truths can bring a renewed enthusiasm into your life .
#
# Spanish:	Concluyo con algunas verdades acerca de las bendiciones del sacerdocio .
# Translation:	I close some truths about the priesthood blessings .
# Target:		I close with some truths about the blessings of the priesthood .
#
# Spanish:	Pidan ser llenos del poder del amor puro de Cristo .
# Translation:	Ask for the power of the pure love of Christ .
# Target:		Ask to be filled with the power of Christ ’s pure love .
#
# Spanish:	las bendiciones del Señor reposarán sobre ustedes y su casa .
# Translation:	blessings of the Lord shall be lifted up upon you .
# Target:		The blessings of the Lord will rest upon you and your house .
#
# Spanish:	Diez años después , decidí agregar otras líneas al poema :
# Translation:	Ten years later , I decided to add to the pulpit :
# Target:		Ten years later , I decided to add a few more lines to that poem :
#
# Spanish:	Estas preguntas universales ya no tienen necesidad de permanecer sin respuesta .
# Translation:	These questions have no need not be need to stand up .
# Target:		No longer need these universal questions remain unanswered .
#
# Spanish:	Ese es el mismo modelo sagrado que permite recibir revelación personal .
# Translation:	This is the same pattern that enables us to receive revelation .
# Target:		This is the same sacred pattern that allows personal revelation .
#
# Spanish:	Ronald A. Rasband participa en la transmisión de Cara a Cara .
# Translation:	I A. Rasband ’s favorite broadcast .
# Target:		Ronald A. Rasband participates in a Face to Face broadcast .
#
# Spanish:	Una de las bendiciones de la paralización llegó en forma inusual .
# Translation:	A few blessings of the blessings came to more than .
# Target:		But one blessing of the freeze came in an unusual way .
#
# Spanish:	Testifico de ello y les dejo mi bendición y mi amor ;
# Translation:	I testify of this and leave my blessing .
# Target:		I so testify and leave you my blessing and my love .
#
# Spanish:	El Señor nos ha enseñado la necesidad de fomentar la autosuficiencia .
# Translation:	The Lord has taught us the need to be self - reliance .
# Target:		The Lord has taught us the need to promote self - reliance .
#
# Spanish:	Mientras estábamos en Escocia , me sentía sola y estaba desanimada .
# Translation:	As we were in trying , I was able to forget and was surprised .
# Target:		While we were in Scotland , I felt especially alone and became discouraged .
#
# Spanish:	Él ha pagado el precio a fin de saber cómo socorrernos .
# Translation:	He has been a price to know how to succor .
# Target:		He has paid the price that He might know how to succor you .
#
# Spanish:	Un himno favorito nos invita a “ escuchar al Salvador ” .
# Translation:	A favorite hymn invites us to “ hear the Savior . ”
# Target:		A favorite hymn pleads with us to “ hear your great Deliv’rer ’s voice ! ”
#
# Spanish:	De modo que , ¿ cómo podemos edificar esas fortificaciones eternas ? .
# Translation:	So how can we build these eternal ?
# Target:		So how do we build these eternal fortifications ?
#
# Spanish:	¿ Podemos vivir a la altura de nuestros compromisos y convenios sagrados ?
# Translation:	Can we live on our priorities and sacred covenants ?
# Target:		Can we live up to our commitments and sacred covenants ?
#
# Spanish:	Qué nuevo aspecto tan maravilloso se ha <unk> a nuestra conferencia general .
# Translation:	What a wonderful lesson has been accomplished in our general conference general conference .
# Target:		What a wonderful new element introduced into our general conference format .
#
# Spanish:	Gordon B. Hinckley , en Hijas en Mi reino , pág. 179 .
# Translation:	Gordon B. Hinckley , in Daughters in My Kingdom , Apr. 1967 , 38 .
# Target:		Gordon B. Hinckley , in Daughters in My Kingdom , 160 .
#
# Spanish:	Éste es mi ruego , en el nombre de Jesucristo . Amén .
# Translation:	This is my prayer , in the name of Jesus Christ , amen .
# Target:		This is my prayer in the name of Jesus Christ , amen .
#
# Spanish:	Recordar — y olvidar — también son parte de nuestra jornada eterna .
# Translation:	To remember and forget — it is part of our eternal journey .
# Target:		Remembering — and forgetting — are also part of our eternal journey .
#
# Spanish:	Cada día debemos considerar incluir interacciones frecuentes con las enseñanzas de Cristo .
# Translation:	We must consider careful to consider personal teachings .
# Target:		Every day we should consider including frequent interactions with the teachings of Christ .
#
# Spanish:	Ahora el coro nos complacerá con : " Considerad los lirios " .
# Translation:	Now the choir will now be with the right . "
# Target:		The choir will now favor us with : " Consider the Lilies . "
#
# Spanish:	Incluso este deseo básico puede <unk> por un deseo aún más importante .
# Translation:	Even this desire can be a desire to be more important .
# Target:		Even this basic desire can be temporarily overridden by an even more important desire .
#
# Spanish:	Sin embargo , aceptaron el llamamiento y suplicaron la ayuda del Señor .
# Translation:	But he accepted the call and asked the Lord .
# Target:		But they accepted the call — and then prayerfully asked for the Lord ’s help .
#
# Spanish:	Observé cuando el secretario caminó hasta la casa del jovencito menos activo .
# Translation:	I saw when the bishop walked down the home of the least of the young boy .
# Target:		I was watching when the secretary walked up the street toward the less - active boy ’s house .
#
# Spanish:	Terry la visitó en el hospital y llevó a Jenny a sus citas ;
# Translation:	A few was at the hospital and took her to his coat .
# Target:		Terry visited the hospital and drove Jenny to appointments .
#
# Spanish:	No obstante , una bienvenida llena de gozo las esperaba en la tierra .
# Translation:	But a few of the joy of joy .
# Target:		A joyous welcome , however , awaited you here on earth .
#
# Spanish:	“ Respondí : ‘ No , élder , ¡ todo está muy bien !
# Translation:	“ I answered , ‘ I do n’t , all is good !
# Target:		“ I responded , ‘ No , Elder , everything is right !
#
# Spanish:	Durante el verano , visité a una encantadora madre joven que tiene hijas .
# Translation:	During the summer , I visited a young mother who has lived .
# Target:		Over the summer I visited with a lovely young mother of daughters .
#
# Spanish:	Era la manera perfecta de experimentar la maravilla y la belleza de volar .
# Translation:	It was the perfect way to experience the memory of the beauty of heavenly .
# Target:		It was the perfect way to experience the wonder and beauty of flight .
#
# Spanish:	Necesitamos mujeres que tengan la valentía y la visión de nuestra madre Eva .
# Translation:	We need women who have the courage and vision of our mother .
# Target:		We need women who have the courage and vision of our Mother Eve .
#
# Spanish:	En el sagrado nombre de nuestro Maestro y Redentor , Jesucristo . Amén .
# Translation:	In the sacred name of our Master and Redeemer , Jesus Christ , amen .
# Target:		In the sacred name of our Master and Redeemer , Jesus Christ , amen .
#
# Spanish:	Les testifico por experiencia propia : El único fracaso es darnos por vencidos .
# Translation:	I testify to you for you — the only is to give .
# Target:		I testify from personal experience : There is no failure except in giving up .
#
# Spanish:	El evangelio de Jesucristo es esa fuente de calor , verdad y fulgor .
# Translation:	The gospel of Jesus Christ is that source of truth , and brightness .
# Target:		That source of warmth , truth , and brightness is the gospel of Jesus Christ .
#
# Spanish:	Como guardianas de la virtud querrán buscar al Salvador en Su santa casa .
# Translation:	As a devoted virtue of the Savior will help you find His holy house .
# Target:		As guardians of virtue , you will want to seek the Savior in His holy house .
#
# Spanish:	Estoy aquí porque deseo de todo corazón seguir a mi Maestro , Jesucristo .
# Translation:	I am here because of all love my Master , Jesus Christ , Jesus Christ .
# Target:		I am here because I desire with all my heart to follow my Master , Jesus Christ .
#
# Spanish:	Ustedes sirven bien y de buena gana , y llevan a cabo grandes cosas .
# Translation:	You serve good and so much of good .
# Target:		You serve willingly and well and accomplish great good .
#
# Spanish:	( 84 ) Una madre joven recibe servicio de parte de sus maestras visitantes .
# Translation:	( 16 ) A young mother receives a young man ’s missionary .
# Target:		( 84 ) Young mother is served by her visiting teacher .
#
# Spanish:	Puede que se hayan encontrado con nuestros misioneros , y tal vez los <unk> .
# Translation:	You can have found our missionaries , and perhaps perhaps the clay to them .
# Target:		You may have previously encountered , or even ignored , our missionaries .
#
# Spanish:	Vyacheslav Efimov fue el presidente de la Misión Rusia <unk> de 1995 a 1998 .
# Translation:	We would be the President of the South Mission .
# Target:		Vyacheslav Efimov was president of the Russia <unk> Mission from 1995 to 1998 .
#
# Spanish:	Eso es lo que los profetas hacen por nosotros : nos conducen hacia Dios .
# Translation:	This is what prophets do to be for us : He understand us .
# Target:		That is what prophets do for us . They lead us to God .
#
# Spanish:	“ Persevera en tu camino ” es una decisión clave en tiempos de prueba .
# Translation:	“ Hold on thy way ” is a key to trial .
# Target:		“ Hold on thy way ” is a key choice during times of trial .
#
# Spanish:	Para que el arrepentimiento surta efecto , debe ser específico , profundo y duradero .
# Translation:	For repentance , it must be a specific and deep , deep .
# Target:		For repentance to work , it must be specific , profound , and lasting .
#
# Spanish:	A fin de ejercer Su poder , debemos esforzarnos para ser como el Salvador .
# Translation:	To exercise His power , we must strive to be like the Savior .
# Target:		In order to exercise His power , we must strive to be like the Savior .
#
# Spanish:	Estoy especialmente agradecido por la presencia de nuestro amado profeta , Thomas S. Monson .
# Translation:	I am especially grateful for the presence of our beloved prophet , Thomas S. Monson .
# Target:		I am especially grateful for the presence of our beloved prophet , Thomas S. Monson .
#
# Spanish:	enseñar y bautizar ¡ para llevar gozo a la gente de todo el mundo !
# Translation:	We teach and honor them to bring the people of all the world !
# Target:		Rather , our missionaries teach and baptize to bring joy to the people of the world !
#
# Spanish:	Por otra parte , la luz nos permite ver las cosas como realmente son .
# Translation:	On another part , the light enables us to see the things like it .
# Target:		Light , on the other hand , allows us to see things as they really are .
#
# Spanish:	Para poder ayudar al Salvador , debemos trabajar juntos , unidos y en armonía .
# Translation:	To help help the Savior , we must work together together together together , and in harmony .
# Target:		In order to assist the Savior , we have to work together in unity and in harmony .
#
# Spanish:	Debemos poder declarar como Alma : “ Sé estas cosas por mí mismo ” .
# Translation:	We must have power as Alma , “ I know these things for me . ”
# Target:		We must be able to declare , as Alma did , “ I … know these things of myself . ”
#
# Spanish:	Sólo el uno por ciento de la población es cristiana en esta nación principalmente budista .
# Translation:	Only one percent of the Church is in this country .
# Target:		Christians are only 1 percent of this principally Buddhist country .
#
# Spanish:	Un día me llegó una postal de una miembro de la Iglesia de mi ciudad .
# Translation:	A Latter - day Saints became a member of the Church .
# Target:		One day I received a postcard from a Church member back home .
#
# Spanish:	Cuando su amigo le expresó lo que pensaba , Brian sintió la confirmación del Espíritu .
# Translation:	When his friend expressed what she thought , he felt the confirmation of the Spirit .
# Target:		As his friend expressed his feelings , Brian felt the Spirit ’s confirmation .
#
# Spanish:	Aquí está su consejo profético e inspirado de siempre para sus hijas y para ustedes .
# Translation:	Here is your prophetic counsel and inspired your daughters .
# Target:		Here is his prophetic and inspired counsel for his daughters and for you always .
#
# Spanish:	En 3 Nefi 26 , el Salvador nos mostró la capacidad espiritual de los niños :
# Translation:	In 3 Nephi 26 , the Savior showed us the spiritual capacity of children :
# Target:		In 3 Nephi 26 , the Savior showed us the spiritual capacity of children :
#
# Spanish:	Se determinó que tenía piedras en los riñones y se le recetó el tratamiento adecuado .
# Translation:	It was a golden news in the outcome and was used to the clay .
# Target:		It was determined that he had a kidney stone , and appropriate treatment was undertaken .
#
# Spanish:	La oración del momento y las rápidas <unk> de las Escrituras no son suficiente preparación .
# Target:		The Lord will offer the opportunities , but whether we are prepared will depend on us .
#
# Spanish:	Todos enfrentamos el fracaso en las responsabilidades personales , las relaciones familiares o en los empleos .
# Translation:	We all face problems in personal relationships , family relationships , or in families .
# Target:		We all experience failure in our personal responsibilities , our family relationships , or our occupations .
#
# Spanish:	Lo hacen en una hermosa y sagrada sala de sellamientos disponible para todos los miembros dignos .
# Translation:	You do a beautiful and sacred room for all members .
# Target:		They do this in a beautiful , sacred sealing room available to all temple - worthy members .
#
# Spanish:	¿ No tenían valor para hablar con determinación contra las críticas y los mensajes del mundo ?
# Translation:	Do n’t have courage to speak to the natural media and messages of the world ?
# Target:		Did they not have the courage to speak boldly against the criticisms or messages of the world ?
#
# Spanish:	La definición también nos permite contemplar la función esencial de la fe al recibir un milagro .
# Translation:	The ultimate goal enables us to ponder the essential role of faith .
# Target:		This definition also allows us to contemplate the vital role of faith in the receipt of a miracle .
#
# Spanish:	Cuando socorremos a alguien , el Salvador lo considera como si lo hubiéramos socorrido a Él .
# Translation:	When we strive to someone else in what if we had to save Him .
# Target:		When we offer succor to anyone , the Savior feels it as if we reached out to succor Him .
#
# Spanish:	Linda K. Burton , “ Fui forastero ” , Liahona , mayo de 2016 , 14 .
# Translation:	Linda K. Burton , “ I Was a Stranger , ” Ensign or Liahona , Apr. 2016 , 14 .
# Target:		Linda K. Burton , “ I Was a Stranger , ” Ensign or Liahona , May 2016 , 14 .
#
# Spanish:	Yo uso “ meditizar ” en español , que es la combinación de meditar y memorizar .
# Translation:	I use “ English in English , ” the combination of ponder and Personal Progress .
# Target:		I use meditizar in Spanish , which is a combination of meditar ( to ponder ) and memorizar ( to memorize ) .
#
# Spanish:	El arrepentimiento no solo es posible , sino que también es gozoso , gracias a nuestro Salvador .
# Translation:	Repentance is not only it is not just a time but it is also full of our Savior .
# Target:		Repentance is not only possible but also joyful because of our Savior .
#
# Spanish:	Entre una batalla y otra , el capitán Moroni dirigió la <unk> de las ciudades menos protegidas .
# Translation:	Among a battle and another Captain Moroni spoke to the cities of the least of small cities .
# Target:		In between the many battles , Captain Moroni directed fortification of the weakest cities .
#
# Spanish:	Otros élderes que salgan a la misión tendrán la experiencia más feliz que tuvo mi hijo Matthew .
# Translation:	Others to go to the mission will have the most happy experience my son .
# Target:		Other elders going into the field will have the happier experience my son Matthew had .
#
# Spanish:	Véase Enseñanzas de los Presidentes de la Iglesia : José Smith , 2007 , págs . <unk> .
# Translation:	See Teachings of Presidents of the Church : Joseph Smith ( 2007 ) , 522 .
# Target:		See Teachings of Presidents of the Church : Joseph Smith ( 2007 ) , <unk> .
#
# Spanish:	Ni “ tampoco podemos nosotros ser perfeccionados sin nuestros muertos ” ( D. y C. <unk> ) .
# Translation:	“ We can not be perfected without our dead ” ( D&C 45:26 ) .
# Target:		And “ neither can we without our dead be made perfect ” ( D&C <unk> ) .
#
# Spanish:	Queridas hermanas , muchas de ustedes son infinitamente compasivas y pacientes con las debilidades de los demás .
# Translation:	Dear sisters , many of you are priceless and patient with weaknesses .
# Target:		Dear sisters , many of you are endlessly compassionate and patient with the weaknesses of others .
#
# Spanish:	“ ‘ Sí ’ , le responde el obispo , ‘ te llamas mi hermano ’ ” .
# Translation:	“ Yes , ’ Yes , ‘ I did n’t leave my brother . ’ ’ ”
# Target:		“ ‘ Yes , ’ replied the Bishop , ‘ you are called my brother . ’ ”
#
# Spanish:	Él me preguntó si el Libro de Mormón era verdadero y si José Smith era un profeta .
# Translation:	He asked if the Book of Mormon was true and if Joseph Smith was a prophet .
# Target:		He asked me if the Book of Mormon was true and if Joseph Smith was a prophet .
#
# Spanish:	Históricamente , el tamaño de ese <unk> ha variado de cuatro días hasta tres años y medio .
# Translation:	Listen , the size of that you have been able to announce three years .
# Target:		Historically , that interval has varied in length from four days to three and a half years .
#
# Spanish:	Que así sea , es mi ferviente oración , en el sagrado nombre de Jesucristo . Amén .
# Translation:	May it is my prayer in the sacred name of Jesus Christ , amen .
# Target:		That such may be so is my earnest prayer in the sacred name of Jesus Christ , amen .
#
# Spanish:	Cuando seguimos a nuestro profeta viviente , el presidente Thomas S. Monson , estamos mirando hacia Jesucristo .
# Translation:	When we follow our living prophet , President Thomas S. Monson , we are watching toward Jesus Christ .
# Target:		When we follow our living prophet , President Thomas S. Monson , we look up to Jesus Christ .
#
# Spanish:	<unk> hoy la decisión de actuar y diga : Sí , Señor , ¡ yo te seguiré !
# Translation:	Let us consider the decision to act and say , Lord , Lord , I will follow me !
# Target:		Make the decision today to act and say , “ Yes , Lord , I will follow Thee ! ”
#
# Spanish:	No podían entender cómo su propio hijo y la familia de Bayley podían soportar la pesada carga .
# Translation:	They could not understand how their own son and family could endure the burden .
# Target:		They could not understand how their own son , along with Bayley ’s family , could bear their heavy burden .
#
# Spanish:	“ Yo sé que mi Redentor vive , y que al final se levantará sobre el polvo .
# Translation:	“ I know that my Redeemer lives , and that the end will be lifted upon the end of the earth .
# Target:		“ For I know that my redeemer liveth , and that he shall stand at the latter day upon the earth :
#
# Spanish:	La Primera Presidencia ha emitido el siguiente informe estadístico de la Iglesia al 31 de diciembre de 2009 .
# Translation:	The First Presidency has issued the following statistical report of the Church in December 31 , 2009 .
# Target:		Church Units
#
# Spanish:	El hermano mayor consoló al menor y , con cuidado , lo ayudó a entrar en la casa .
# Translation:	Brother Brems prayed to the little and with them , they helped them enter into the home .
# Target:		The older brother <unk> and carefully helped the younger brother back into the house .
#
# Spanish:	He tenido la bendición de ser llamado a seguir a líderes inspirados durante gran parte de mi vida .
# Translation:	I have had a blessing to follow the leaders of my life .
# Target:		I have been blessed to be called to follow inspired leaders much of my life .
#
# Spanish:	Piensen cuánto más se logró que si lo hubiese ordenado otra persona , aunque hubiera sido un apóstol .
# Translation:	Think of how if if if he had been ordained another person .
# Target:		Think how much more was accomplished than if another had ordained him , even an Apostle .
#
# Spanish:	¿ No vemos todos el mundo a través de las enormes limitaciones de nuestra propia experiencia de vida ?
# Translation:	Do n’t we see all the world through our own experience of our own experience ?
# Target:		Do n’t we all see the world though the enormous limitations of our own life experience ?
#
# Spanish:	Página 86 : El presidente Thomas S. Monson nos pidió que sigamos a Jesucristo para ser buenos ejemplos .
